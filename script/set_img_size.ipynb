# %%
import os
from PIL import Image

import os
import shutil
from sklearn.model_selection import train_test_split

# %%
# 이미지가 저장된 최상위 폴더 경로
base_dir = "../dataset/img_dataset"
# 원하는 해상도 설정 (예: 256x256)
target_size = (256, 256)

# 폴더 내 모든 차트 패턴 폴더 탐색
for pattern_dir in os.listdir(base_dir):
    pattern_path = os.path.join(base_dir, pattern_dir)
    # 폴더 내 이미지 파일 탐색
    if os.path.isdir(pattern_path):
        for img_name in os.listdir(pattern_path):
            img_path = os.path.join(pattern_path, img_name)
            # 이미지 파일만 처리
            if img_path.endswith('.jpg') or img_path.endswith('.png'):
                try:
                    # 이미지 열기
                    img = Image.open(img_path)
                    # 해상도 변경
                    img_resized = img.resize(target_size, Image.Resampling.LANCZOS)
                    # 동일 경로에 저장 (덮어쓰기)
                    img_resized.save(img_path)
                    print(f"Resized and saved: {img_path}")
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")
# Out:
# Resized and saved: ../img_dataset/DTr/DTr_11.jpg
# Resized and saved: ../img_dataset/DTr/DTr_05.jpg
# Resized and saved: ../img_dataset/DTr/DTr_04.jpg
# Resized and saved: ../img_dataset/DTr/DTr_10.jpg
# Resized and saved: ../img_dataset/DTr/DTr_06.jpg
# Resized and saved: ../img_dataset/DTr/DTr_12.jpg
# Resized and saved: ../img_dataset/DTr/DTr_13.jpg
# Resized and saved: ../img_dataset/DTr/DTr_07.jpg
# Resized and saved: ../img_dataset/DTr/DTr_03.jpg
# Resized and saved: ../img_dataset/DTr/DTr_17.jpg
# Resized and saved: ../img_dataset/DTr/DTr_16.jpg
# Resized and saved: ../img_dataset/DTr/DTr_02.jpg
# Resized and saved: ../img_dataset/DTr/DTr_28.jpg
# Resized and saved: ../img_dataset/DTr/DTr_14.jpg
# Resized and saved: ../img_dataset/DTr/DTr_01.jpg
# Resized and saved: ../img_dataset/DTr/DTr_15.jpg
# Resized and saved: ../img_dataset/DTr/DTr_29.jpg
# Resized and saved: ../img_dataset/DTr/DTr_30.jpg
# Resized and saved: ../img_dataset/DTr/DTr_24.jpg
# Resized and saved: ../img_dataset/DTr/DTr_18.jpg
# Resized and saved: ../img_dataset/DTr/DTr_19.jpg
# Resized and saved: ../img_dataset/DTr/DTr_25.jpg
# Resized and saved: ../img_dataset/DTr/DTr_27.jpg
# Resized and saved: ../img_dataset/DTr/DTr_26.jpg
# Resized and saved: ../img_dataset/DTr/DTr_22.jpg
# Resized and saved: ../img_dataset/DTr/DTr_23.jpg
# Resized and saved: ../img_dataset/DTr/DTr_09.jpg
# Resized and saved: ../img_dataset/DTr/DTr_21.jpg
# Resized and saved: ../img_dataset/DTr/DTr_20.jpg
# Resized and saved: ../img_dataset/DTr/DTr_08.jpg
# Resized and saved: ../img_dataset/DT/DT_20.jpg
# Resized and saved: ../img_dataset/DT/DT_08.jpg
# Resized and saved: ../img_dataset/DT/DT_09.jpg
# Resized and saved: ../img_dataset/DT/DT_21.jpg
# Resized and saved: ../img_dataset/DT/DT_23.jpg
# Resized and saved: ../img_dataset/DT/DT_22.jpg
# Resized and saved: ../img_dataset/DT/DT_26.jpg
# Resized and saved: ../img_dataset/DT/DT_27.jpg
# Resized and saved: ../img_dataset/DT/DT_19.jpg
# Resized and saved: ../img_dataset/DT/DT_25.jpg
# Resized and saved: ../img_dataset/DT/DT_30.jpg
# Resized and saved: ../img_dataset/DT/DT_24.jpg
# Resized and saved: ../img_dataset/DT/DT_18.jpg
# Resized and saved: ../img_dataset/DT/DT_01.jpg
# Resized and saved: ../img_dataset/DT/DT_15.jpg
# Resized and saved: ../img_dataset/DT/DT_29.jpg
# Resized and saved: ../img_dataset/DT/DT_28.jpg
# Resized and saved: ../img_dataset/DT/DT_14.jpg
# Resized and saved: ../img_dataset/DT/DT_16.jpg
# Resized and saved: ../img_dataset/DT/DT_02.jpg
# Resized and saved: ../img_dataset/DT/DT_03.jpg
# Resized and saved: ../img_dataset/DT/DT_17.jpg
# Resized and saved: ../img_dataset/DT/DT_13.jpg
# Resized and saved: ../img_dataset/DT/DT_07.jpg
# Resized and saved: ../img_dataset/DT/DT_06.jpg
# Resized and saved: ../img_dataset/DT/DT_12.jpg
# Resized and saved: ../img_dataset/DT/DT_04.jpg
# Resized and saved: ../img_dataset/DT/DT_10.jpg
# Resized and saved: ../img_dataset/DT/DT_11.jpg
# Resized and saved: ../img_dataset/DT/DT_05.jpg
# Resized and saved: ../img_dataset/FW/FW_28.jpg
# Resized and saved: ../img_dataset/FW/FW_14.jpg
# Resized and saved: ../img_dataset/FW/FW_01.jpg
# Resized and saved: ../img_dataset/FW/FW_15.jpg
# Resized and saved: ../img_dataset/FW/FW_29.jpg
# Resized and saved: ../img_dataset/FW/FW_03.jpg
# Resized and saved: ../img_dataset/FW/FW_17.jpg
# Resized and saved: ../img_dataset/FW/FW_16.jpg
# Resized and saved: ../img_dataset/FW/FW_02.jpg
# Resized and saved: ../img_dataset/FW/FW_06.jpg
# Resized and saved: ../img_dataset/FW/FW_12.jpg
# Resized and saved: ../img_dataset/FW/FW_13.jpg
# Resized and saved: ../img_dataset/FW/FW_07.jpg
# Resized and saved: ../img_dataset/FW/FW_11.jpg
# Resized and saved: ../img_dataset/FW/FW_05.jpg
# Resized and saved: ../img_dataset/FW/FW_04.jpg
# Resized and saved: ../img_dataset/FW/FW_10.jpg
# Resized and saved: ../img_dataset/FW/FW_09.jpg
# Resized and saved: ../img_dataset/FW/FW_21.jpg
# Resized and saved: ../img_dataset/FW/FW_20.jpg
# Resized and saved: ../img_dataset/FW/FW_08.jpg
# Resized and saved: ../img_dataset/FW/FW_22.jpg
# Resized and saved: ../img_dataset/FW/FW_23.jpg
# Resized and saved: ../img_dataset/FW/FW_27.jpg
# Resized and saved: ../img_dataset/FW/FW_26.jpg
# Resized and saved: ../img_dataset/FW/FW_30.jpg
# Resized and saved: ../img_dataset/FW/FW_24.jpg
# Resized and saved: ../img_dataset/FW/FW_18.jpg
# Resized and saved: ../img_dataset/FW/FW_19.jpg
# Resized and saved: ../img_dataset/FW/FW_25.jpg
# Resized and saved: ../img_dataset/DB/DB_18.jpg
# Resized and saved: ../img_dataset/DB/DB_24.jpg
# Resized and saved: ../img_dataset/DB/DB_30.jpg
# Resized and saved: ../img_dataset/DB/DB_25.jpg
# Resized and saved: ../img_dataset/DB/DB_19.jpg
# Resized and saved: ../img_dataset/DB/DB_27.jpg
# Resized and saved: ../img_dataset/DB/DB_26.jpg
# Resized and saved: ../img_dataset/DB/DB_22.jpg
# Resized and saved: ../img_dataset/DB/DB_23.jpg
# Resized and saved: ../img_dataset/DB/DB_21.jpg
# Resized and saved: ../img_dataset/DB/DB_09.jpg
# Resized and saved: ../img_dataset/DB/DB_08.jpg
# Resized and saved: ../img_dataset/DB/DB_20.jpg
# Resized and saved: ../img_dataset/DB/DB_05.jpg
# Resized and saved: ../img_dataset/DB/DB_11.jpg
# Resized and saved: ../img_dataset/DB/DB_10.jpg
# Resized and saved: ../img_dataset/DB/DB_04.jpg
# Resized and saved: ../img_dataset/DB/DB_12.jpg
# Resized and saved: ../img_dataset/DB/DB_06.jpg
# Resized and saved: ../img_dataset/DB/DB_07.jpg
# Resized and saved: ../img_dataset/DB/DB_13.jpg
# Resized and saved: ../img_dataset/DB/DB_17.jpg
# Resized and saved: ../img_dataset/DB/DB_03.jpg
# Resized and saved: ../img_dataset/DB/DB_02.jpg
# Resized and saved: ../img_dataset/DB/DB_16.jpg
# Resized and saved: ../img_dataset/DB/DB_14.jpg
# Resized and saved: ../img_dataset/DB/DB_28.jpg
# Resized and saved: ../img_dataset/DB/DB_29.jpg
# Resized and saved: ../img_dataset/DB/DB_15.jpg
# Resized and saved: ../img_dataset/DB/DB_01.jpg
# Resized and saved: ../img_dataset/ATr/ATr_27.jpg
# Resized and saved: ../img_dataset/ATr/ATr_26.jpg
# Resized and saved: ../img_dataset/ATr/ATr_24.jpg
# Resized and saved: ../img_dataset/ATr/ATr_30.jpg
# Resized and saved: ../img_dataset/ATr/ATr_18.jpg
# Resized and saved: ../img_dataset/ATr/ATr_19.jpg
# Resized and saved: ../img_dataset/ATr/ATr_25.jpg
# Resized and saved: ../img_dataset/ATr/ATr_09.jpg
# Resized and saved: ../img_dataset/ATr/ATr_21.jpg
# Resized and saved: ../img_dataset/ATr/ATr_20.jpg
# Resized and saved: ../img_dataset/ATr/ATr_08.jpg
# Resized and saved: ../img_dataset/ATr/ATr_22.jpg
# Resized and saved: ../img_dataset/ATr/ATr_23.jpg
# Resized and saved: ../img_dataset/ATr/ATr_12.jpg
# Resized and saved: ../img_dataset/ATr/ATr_06.jpg
# Resized and saved: ../img_dataset/ATr/ATr_07.jpg
# Resized and saved: ../img_dataset/ATr/ATr_13.jpg
# Resized and saved: ../img_dataset/ATr/ATr_05.jpg
# Resized and saved: ../img_dataset/ATr/ATr_11.jpg
# Resized and saved: ../img_dataset/ATr/ATr_10.jpg
# Resized and saved: ../img_dataset/ATr/ATr_04.jpg
# Resized and saved: ../img_dataset/ATr/ATr_28.jpg
# Resized and saved: ../img_dataset/ATr/ATr_14.jpg
# Resized and saved: ../img_dataset/ATr/ATr_15.jpg
# Resized and saved: ../img_dataset/ATr/ATr_01.jpg
# Resized and saved: ../img_dataset/ATr/ATr_29.jpg
# Resized and saved: ../img_dataset/ATr/ATr_17.jpg
# Resized and saved: ../img_dataset/ATr/ATr_03.jpg
# Resized and saved: ../img_dataset/ATr/ATr_02.jpg
# Resized and saved: ../img_dataset/ATr/ATr_16.jpg
# Resized and saved: ../img_dataset/STr/STr_26.jpg
# Resized and saved: ../img_dataset/STr/STr_27.jpg
# Resized and saved: ../img_dataset/STr/STr_19.jpg
# Resized and saved: ../img_dataset/STr/STr_25.jpg
# Resized and saved: ../img_dataset/STr/STr_30.jpg
# Resized and saved: ../img_dataset/STr/STr_24.jpg
# Resized and saved: ../img_dataset/STr/STr_18.jpg
# Resized and saved: ../img_dataset/STr/STr_20.jpg
# Resized and saved: ../img_dataset/STr/STr_08.jpg
# Resized and saved: ../img_dataset/STr/STr_09.jpg
# Resized and saved: ../img_dataset/STr/STr_21.jpg
# Resized and saved: ../img_dataset/STr/STr_23.jpg
# Resized and saved: ../img_dataset/STr/STr_22.jpg
# Resized and saved: ../img_dataset/STr/STr_13.jpg
# Resized and saved: ../img_dataset/STr/STr_07.jpg
# Resized and saved: ../img_dataset/STr/STr_06.jpg
# Resized and saved: ../img_dataset/STr/STr_12.jpg
# Resized and saved: ../img_dataset/STr/STr_04.jpg
# Resized and saved: ../img_dataset/STr/STr_11.jpg
# Resized and saved: ../img_dataset/STr/STr_05.jpg
# Resized and saved: ../img_dataset/STr/STr_01.jpg
# Resized and saved: ../img_dataset/STr/STr_15.jpg
# Resized and saved: ../img_dataset/STr/STr_29.jpg
# Resized and saved: ../img_dataset/STr/STr_28.jpg
# Resized and saved: ../img_dataset/STr/STr_14.jpg
# Resized and saved: ../img_dataset/STr/STr_16.jpg
# Resized and saved: ../img_dataset/STr/STr_02.jpg
# Resized and saved: ../img_dataset/STr/STr_010.jpg
# Resized and saved: ../img_dataset/STr/STr_03.jpg
# Resized and saved: ../img_dataset/STr/STr_17.jpg
# Resized and saved: ../img_dataset/RW/RW_11.jpg
# Resized and saved: ../img_dataset/RW/RW_05.jpg
# Resized and saved: ../img_dataset/RW/RW_04.jpg
# Resized and saved: ../img_dataset/RW/RW_10.jpg
# Resized and saved: ../img_dataset/RW/RW_06.jpg
# Resized and saved: ../img_dataset/RW/RW_12.jpg
# Resized and saved: ../img_dataset/RW/RW_13.jpg
# Resized and saved: ../img_dataset/RW/RW_07.jpg
# Resized and saved: ../img_dataset/RW/RW_03.jpg
# Resized and saved: ../img_dataset/RW/RW_17.jpg
# Resized and saved: ../img_dataset/RW/RW_16.jpg
# Resized and saved: ../img_dataset/RW/RW_02.jpg
# Resized and saved: ../img_dataset/RW/RW_28.jpg
# Resized and saved: ../img_dataset/RW/RW_14.jpg
# Resized and saved: ../img_dataset/RW/RW_01.jpg
# Resized and saved: ../img_dataset/RW/RW_15.jpg
# Resized and saved: ../img_dataset/RW/RW_29.jpg
# Resized and saved: ../img_dataset/RW/RW_30.jpg
# Resized and saved: ../img_dataset/RW/RW_24.jpg
# Resized and saved: ../img_dataset/RW/RW_18.jpg
# Resized and saved: ../img_dataset/RW/RW_19.jpg
# Resized and saved: ../img_dataset/RW/RW_25.jpg
# Resized and saved: ../img_dataset/RW/RW_27.jpg
# Resized and saved: ../img_dataset/RW/RW_26.jpg
# Resized and saved: ../img_dataset/RW/RW_22.jpg
# Resized and saved: ../img_dataset/RW/RW_23.jpg
# Resized and saved: ../img_dataset/RW/RW_09.jpg
# Resized and saved: ../img_dataset/RW/RW_21.jpg
# Resized and saved: ../img_dataset/RW/RW_20.jpg
# Resized and saved: ../img_dataset/RW/RW_08.jpg

# %%
# 원본 데이터셋 폴더 경로
base_dir = "../dataset/img_dataset"
# 출력 폴더 경로
output_base_dir = "../dataset/processed_img_dataset"

# 학습, 검증, 테스트 비율 설정
train_ratio = 0.7
test_ratio = 0.2
val_ratio = 0.1

# 폴더 생성
os.makedirs(output_base_dir, exist_ok=True)
train_dir = os.path.join(output_base_dir, 'train')
val_dir = os.path.join(output_base_dir, 'val')
test_dir = os.path.join(output_base_dir, 'test')

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# 각 차트 패턴 폴더 탐색 및 파일 리스트 수집
for pattern_dir in os.listdir(base_dir):
    pattern_path = os.path.join(base_dir, pattern_dir)
    if os.path.isdir(pattern_path):
        images = [img for img in os.listdir(pattern_path) if img.endswith('.jpg') or img.endswith('.png')]
        
        # 학습, 테스트, 검증 데이터로 분할
        train_imgs, test_imgs = train_test_split(images, test_size=(1 - train_ratio), random_state=42)
        val_imgs, test_imgs = train_test_split(test_imgs, test_size=(test_ratio / (test_ratio + val_ratio)), random_state=42)
        
        # 파일 복사 함수
        def copy_files(img_list, src_dir, dest_dir):
            os.makedirs(dest_dir, exist_ok=True)
            for img in img_list:
                src_path = os.path.join(src_dir, img)
                dest_path = os.path.join(dest_dir, img)
                shutil.copyfile(src_path, dest_path)

        # 이미지 파일 복사
        copy_files(train_imgs, pattern_path, os.path.join(train_dir, pattern_dir))
        copy_files(val_imgs, pattern_path, os.path.join(val_dir, pattern_dir))
        copy_files(test_imgs, pattern_path, os.path.join(test_dir, pattern_dir))

print("Dataset has been split into train, val, and test sets.")
# Out:
# Dataset has been split into train, val, and test sets.
