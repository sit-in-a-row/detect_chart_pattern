# %%
from generate_pattern import generate_pattern, get_pattern_graph
from store_datasets import store_datasets

# %%
pattern_list = ['ascending_triangle', 'ascending_wedge', 'descending_triangle', 'descending_wedge', 'double_top', 'double_bottom']

# %%
for pattern in pattern_list:
    store_datasets(pattern, 10000, False)
# Out:
# 1/10000 Done
# 2/10000 Done
# 3/10000 Done
# 4/10000 Done
# 5/10000 Done
# 6/10000 Done
# 7/10000 Done
# 8/10000 Done
# 9/10000 Done
# 10/10000 Done
# 11/10000 Done
# 12/10000 Done
# 13/10000 Done
# 14/10000 Done
# 15/10000 Done
# 16/10000 Done
# 17/10000 Done
# 18/10000 Done
# 19/10000 Done
# 20/10000 Done
# 21/10000 Done
# 22/10000 Done
# 23/10000 Done
# 24/10000 Done
# 25/10000 Done
# 26/10000 Done
# 27/10000 Done
# 28/10000 Done
# 29/10000 Done
# 30/10000 Done
# 31/10000 Done
# 32/10000 Done
# 33/10000 Done
# 34/10000 Done
# 35/10000 Done
# 36/10000 Done
# 37/10000 Done
# 38/10000 Done
# 39/10000 Done
# 40/10000 Done
# 41/10000 Done
# 42/10000 Done
# 43/10000 Done
# 44/10000 Done
# 45/10000 Done
# 46/10000 Done
# 47/10000 Done
# 48/10000 Done
# 49/10000 Done
# 50/10000 Done
# 51/10000 Done
# 52/10000 Done
# 53/10000 Done
# 54/10000 Done
# 55/10000 Done
# 56/10000 Done
# 57/10000 Done
# 58/10000 Done
# 59/10000 Done
# 60/10000 Done
# 61/10000 Done
# 62/10000 Done
# 63/10000 Done
# ...

# %%
# store_datasets('double_top', 3, True)
