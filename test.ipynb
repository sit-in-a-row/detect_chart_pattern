# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping

# 데이터 로드 함수
def load_data(pattern, num):
    path = f'algo_dataset/{pattern}/{pattern}_{num}.csv'
    df = pd.read_csv(path)
    return df

# 슬라이딩 윈도우 생성 함수
def create_sliding_window(data, window_size):
    sliding_windows = []
    for i in range(len(data) - window_size + 1):
        sliding_windows.append(data[i:i+window_size])
    return np.array(sliding_windows)

# 패턴 리스트
patterns = ['ascending_triangle', 'descending_triangle', 'ascending_wedge', 'descending_wedge', 'double_top', 'double_bottom']
window_size = 70  # 윈도우 크기 설정
data = []

# 모든 패턴 데이터를 불러오고 슬라이딩 윈도우 적용
for pattern in patterns:
    for i in range(1000):  # 각 패턴에 1000개의 데이터가 있음
        df = load_data(pattern, i+1)
        scaled_data = MinMaxScaler().fit_transform(df[['Open', 'High', 'Low', 'Close', 'Volume']].values)
        windows = create_sliding_window(scaled_data, window_size)
        data.extend([(window, pattern) for window in windows])

# 데이터를 학습용, 테스트용으로 분리합니다.
train_data, test_data = train_test_split(data, test_size=0.2, shuffle=True)

# 데이터 전처리 함수
def prepare_data(data):
    X, y = [], []
    for window, label in data:
        X.append(window)
        y.append(patterns.index(label))  # 패턴 이름을 숫자로 변환

    X = np.array(X)
    y = tf.keras.utils.to_categorical(y, num_classes=6)  # 6개의 클래스에 대한 one-hot encoding

    return X, y

# 학습 데이터 및 테스트 데이터 전처리
X_train, y_train = prepare_data(train_data)
X_test, y_test = prepare_data(test_data)

# 모델 생성 함수
def create_model():
    model = Sequential()

    # CNN Layers
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(window_size, 5)))  # window_size는 OHLCV 데이터의 길이
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))

    # LSTM Layer
    model.add(LSTM(128, return_sequences=False))
    model.add(Dropout(0.3))

    # Fully Connected Layer
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(6, activation='softmax'))  # 6개의 패턴에 대한 확률 출력

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# 모델 생성
model = create_model()

# Early stopping을 사용해 과적합 방지
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 학습
model.fit(X_train, y_train, 
          epochs=50, 
          batch_size=64, 
          validation_data=(X_test, y_test), 
          callbacks=[early_stopping])

# 최종 성능 평가
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Final test accuracy: {accuracy:.4f}")
# Out:
# /opt/anaconda3/envs/finTF/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 184s 35ms/step - accuracy: 0.5958 - loss: 0.8629 - val_accuracy: 0.7918 - val_loss: 0.4520
# Epoch 2/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 171s 33ms/step - accuracy: 0.7910 - loss: 0.4711 - val_accuracy: 0.8284 - val_loss: 0.3883
# Epoch 3/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 169s 32ms/step - accuracy: 0.8150 - loss: 0.4214 - val_accuracy: 0.8405 - val_loss: 0.3673
# Epoch 4/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 206s 39ms/step - accuracy: 0.8297 - loss: 0.3909 - val_accuracy: 0.8480 - val_loss: 0.3490
# Epoch 5/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 205s 39ms/step - accuracy: 0.8402 - loss: 0.3700 - val_accuracy: 0.8488 - val_loss: 0.3531
# Epoch 6/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 188s 36ms/step - accuracy: 0.8494 - loss: 0.3526 - val_accuracy: 0.8580 - val_loss: 0.3238
# Epoch 7/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 179s 34ms/step - accuracy: 0.8571 - loss: 0.3353 - val_accuracy: 0.8677 - val_loss: 0.3059
# Epoch 8/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 202s 39ms/step - accuracy: 0.8608 - loss: 0.3268 - val_accuracy: 0.8758 - val_loss: 0.2956
# Epoch 9/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 218s 42ms/step - accuracy: 0.8676 - loss: 0.3135 - val_accuracy: 0.8830 - val_loss: 0.2805
# Epoch 10/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 269s 51ms/step - accuracy: 0.8710 - loss: 0.3052 - val_accuracy: 0.8837 - val_loss: 0.2747
# Epoch 11/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 241s 46ms/step - accuracy: 0.8760 - loss: 0.2948 - val_accuracy: 0.8885 - val_loss: 0.2678
# Epoch 12/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 422s 80ms/step - accuracy: 0.8775 - loss: 0.2918 - val_accuracy: 0.8939 - val_loss: 0.2577
# Epoch 13/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 208s 40ms/step - accuracy: 0.8821 - loss: 0.2800 - val_accuracy: 0.8977 - val_loss: 0.2515
# Epoch 14/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 279s 53ms/step - accuracy: 0.8854 - loss: 0.2754 - val_accuracy: 0.8970 - val_loss: 0.2500
# Epoch 15/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 267s 51ms/step - accuracy: 0.8893 - loss: 0.2671 - val_accuracy: 0.8994 - val_loss: 0.2454
# Epoch 16/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 269s 51ms/step - accuracy: 0.8897 - loss: 0.2645 - val_accuracy: 0.9020 - val_loss: 0.2389
# Epoch 17/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 240s 46ms/step - accuracy: 0.8932 - loss: 0.2584 - val_accuracy: 0.9024 - val_loss: 0.2370
# Epoch 18/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 227s 43ms/step - accuracy: 0.8942 - loss: 0.2554 - val_accuracy: 0.9024 - val_loss: 0.2377
# Epoch 19/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 226s 43ms/step - accuracy: 0.8969 - loss: 0.2493 - val_accuracy: 0.9008 - val_loss: 0.2369
# Epoch 20/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 232s 44ms/step - accuracy: 0.8988 - loss: 0.2460 - val_accuracy: 0.9100 - val_loss: 0.2207
# Epoch 21/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 242s 46ms/step - accuracy: 0.9014 - loss: 0.2404 - val_accuracy: 0.9116 - val_loss: 0.2208
# Epoch 22/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 277s 53ms/step - accuracy: 0.9038 - loss: 0.2344 - val_accuracy: 0.9135 - val_loss: 0.2150
# Epoch 23/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 256s 49ms/step - accuracy: 0.9064 - loss: 0.2295 - val_accuracy: 0.9179 - val_loss: 0.2082
# Epoch 24/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 263s 50ms/step - accuracy: 0.9068 - loss: 0.2284 - val_accuracy: 0.9182 - val_loss: 0.2052
# Epoch 25/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 223s 42ms/step - accuracy: 0.9095 - loss: 0.2223 - val_accuracy: 0.9210 - val_loss: 0.1979
# Epoch 26/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 232s 44ms/step - accuracy: 0.9112 - loss: 0.2184 - val_accuracy: 0.9226 - val_loss: 0.1949
# Epoch 27/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 233s 44ms/step - accuracy: 0.9131 - loss: 0.2148 - val_accuracy: 0.9189 - val_loss: 0.2012
# Epoch 28/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 216s 41ms/step - accuracy: 0.9160 - loss: 0.2092 - val_accuracy: 0.9209 - val_loss: 0.1926
# Epoch 29/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 238s 45ms/step - accuracy: 0.9170 - loss: 0.2063 - val_accuracy: 0.9285 - val_loss: 0.1796
# Epoch 30/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 203s 39ms/step - accuracy: 0.9192 - loss: 0.2002 - val_accuracy: 0.9294 - val_loss: 0.1770
# Epoch 31/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 203s 39ms/step - accuracy: 0.9206 - loss: 0.1966 - val_accuracy: 0.9342 - val_loss: 0.1675
# Epoch 32/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 203s 39ms/step - accuracy: 0.9224 - loss: 0.1923 - val_accuracy: 0.9346 - val_loss: 0.1648
# Epoch 33/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 194s 37ms/step - accuracy: 0.9245 - loss: 0.1876 - val_accuracy: 0.9371 - val_loss: 0.1586
# Epoch 34/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 199s 38ms/step - accuracy: 0.9275 - loss: 0.1824 - val_accuracy: 0.9417 - val_loss: 0.1522
# Epoch 35/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 183s 35ms/step - accuracy: 0.9302 - loss: 0.1767 - val_accuracy: 0.9417 - val_loss: 0.1473
# Epoch 36/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 187s 36ms/step - accuracy: 0.9315 - loss: 0.1725 - val_accuracy: 0.9431 - val_loss: 0.1439
# Epoch 37/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 195s 37ms/step - accuracy: 0.9333 - loss: 0.1674 - val_accuracy: 0.9467 - val_loss: 0.1348
# Epoch 38/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 188s 36ms/step - accuracy: 0.9365 - loss: 0.1609 - val_accuracy: 0.9434 - val_loss: 0.1393
# Epoch 39/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 192s 37ms/step - accuracy: 0.9377 - loss: 0.1578 - val_accuracy: 0.9489 - val_loss: 0.1334
# Epoch 40/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 180s 34ms/step - accuracy: 0.9401 - loss: 0.1510 - val_accuracy: 0.9535 - val_loss: 0.1208
# Epoch 41/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 181s 34ms/step - accuracy: 0.9430 - loss: 0.1452 - val_accuracy: 0.9589 - val_loss: 0.1103
# Epoch 42/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 191s 36ms/step - accuracy: 0.9436 - loss: 0.1422 - val_accuracy: 0.9559 - val_loss: 0.1126
# Epoch 43/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 206s 39ms/step - accuracy: 0.9462 - loss: 0.1383 - val_accuracy: 0.9627 - val_loss: 0.1007
# Epoch 44/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 212s 40ms/step - accuracy: 0.9482 - loss: 0.1321 - val_accuracy: 0.9652 - val_loss: 0.0970
# Epoch 45/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 217s 41ms/step - accuracy: 0.9495 - loss: 0.1293 - val_accuracy: 0.9608 - val_loss: 0.1032
# Epoch 46/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 217s 41ms/step - accuracy: 0.9520 - loss: 0.1236 - val_accuracy: 0.9615 - val_loss: 0.0994
# Epoch 47/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 198s 38ms/step - accuracy: 0.9531 - loss: 0.1203 - val_accuracy: 0.9702 - val_loss: 0.0814
# Epoch 48/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 229s 44ms/step - accuracy: 0.9557 - loss: 0.1136 - val_accuracy: 0.9675 - val_loss: 0.0838
# Epoch 49/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 206s 39ms/step - accuracy: 0.9565 - loss: 0.1117 - val_accuracy: 0.9740 - val_loss: 0.0731
# Epoch 50/50
# 5250/5250 ━━━━━━━━━━━━━━━━━━━━ 201s 38ms/step - accuracy: 0.9586 - loss: 0.1069 - val_accuracy: 0.9699 - val_loss: 0.0774
# 2625/2625 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9741 - loss: 0.0726
# Final test accuracy: 0.9740

# %%
import os

# 모델 저장 디렉토리 생성
save_dir = './save_model'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# 모델 저장 경로
model_save_path = os.path.join(save_dir, 'chart_pattern_model.h5')

# 모델 저장
model.save(model_save_path)
print(f"Model saved at {model_save_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved at ./save_model/chart_pattern_model.h5

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# 예측을 위한 함수
def predict_pattern(model, ohlcv_data, window_size=70):
    """
    외부에서 입력받은 OHLCV 데이터를 기반으로 6개의 차트 패턴에 대한 확률을 예측하는 함수
    :param model: 학습된 CNN-LSTM 모델
    :param ohlcv_data: 새로운 OHLCV 데이터 (numpy 배열 형태로)
    :param window_size: 모델이 사용한 윈도우 크기 (슬라이딩 윈도우 크기)
    :return: 각 패턴에 속할 확률
    """
    # OHLCV 데이터를 정규화 (외부 데이터)
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(ohlcv_data)

    # 입력 데이터를 슬라이딩 윈도우로 변환
    if len(scaled_data) < window_size:
        raise ValueError(f"Input data length should be at least {window_size}")

    input_data = np.array([scaled_data[-window_size:]])  # 최신 데이터로 슬라이딩 윈도우 생성
    
    # 모델 예측 (확률 반환)
    predictions = model.predict(input_data)

    # 6개의 클래스에 대한 확률 출력
    return predictions[0]  # 예측된 확률

# %%
# DataFrame 분할 함수
def split_df(df, split_window):
    df_length = len(df)

    if df_length < split_window:
        print(f'{split_window} 기준으로 분할할 수 없습니다! 현재 길이: {df_length}')
    
    final_df_list = []

    for i in range(len(df) - split_window):
        df_start_point = i
        df_end_point = i + split_window
        splited_df = df.iloc[df_start_point:df_end_point]
        final_df_list.append(splited_df)

    return final_df_list

# %%
from pykrx import stock

# 삼성전자 주식 데이터 불러오기 (열 이름 변경)
df = stock.get_market_ohlcv("20240101", "20240701", "005930").drop('등락률', axis=1)

# 열 이름을 영어로 변경
df.rename(columns={'시가': 'Open', '고가': 'High', '저가': 'Low', '종가': 'Close', '거래량': 'Volume'}, inplace=True)

# %%
df_list = split_df(df, 70)

# %%
for i in range(len(df_list)):
    predicted_probabilities = predict_pattern(model, df_list[i])

    # 각 패턴에 속할 확률을 출력
    patterns = ['ascending_triangle', 'descending_triangle', 'ascending_wedge', 'descending_wedge', 'double_top', 'double_bottom']
    for pattern, prob in zip(patterns, predicted_probabilities):
        print(f"Pattern: {pattern}, Probability: {prob:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Pattern: ascending_triangle, Probability: 0.0019
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0646
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.9218
# Pattern: double_bottom, Probability: 0.0118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0011
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0586
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.9146
# Pattern: double_bottom, Probability: 0.0258
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Pattern: ascending_triangle, Probability: 0.0092
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.2599
# Pattern: descending_wedge, Probability: 0.0001
# Pattern: double_top, Probability: 0.6510
# Pattern: double_bottom, Probability: 0.0799
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0026
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.1497
# Pattern: descending_wedge, Probability: 0.0004
# Pattern: double_top, Probability: 0.8203
# Pattern: double_bottom, Probability: 0.0269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0124
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.5636
# Pattern: descending_wedge, Probability: 0.0043
# Pattern: double_top, Probability: 0.3877
# Pattern: double_bottom, Probability: 0.0320
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0090
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.4140
# Pattern: descending_wedge, Probability: 0.0248
# Pattern: double_top, Probability: 0.5398
# Pattern: double_bottom, Probability: 0.0125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0192
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.4674
# Pattern: descending_wedge, Probability: 0.0912
# Pattern: double_top, Probability: 0.4159
# Pattern: double_bottom, Probability: 0.0062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0045
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0906
# Pattern: descending_wedge, Probability: 0.1158
# Pattern: double_top, Probability: 0.7888
# Pattern: double_bottom, Probability: 0.0002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0122
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.5950
# Pattern: descending_wedge, Probability: 0.1921
# Pattern: double_top, Probability: 0.2007
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0082
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.2825
# Pattern: descending_wedge, Probability: 0.1772
# Pattern: double_top, Probability: 0.5321
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Pattern: ascending_triangle, Probability: 0.0108
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.1881
# Pattern: descending_wedge, Probability: 0.0833
# Pattern: double_top, Probability: 0.7178
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0208
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0471
# Pattern: descending_wedge, Probability: 0.0638
# Pattern: double_top, Probability: 0.8684
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.5254
# Pattern: descending_triangle, Probability: 0.0009
# Pattern: ascending_wedge, Probability: 0.0087
# Pattern: descending_wedge, Probability: 0.1807
# Pattern: double_top, Probability: 0.2842
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 1.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 1.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 1.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 1.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 1.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 1.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0001
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0001
# Pattern: double_top, Probability: 0.9998
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 1.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0001
# Pattern: double_top, Probability: 0.9998
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.9999
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0001
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0004
# Pattern: double_top, Probability: 0.9994
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0001
# Pattern: double_top, Probability: 0.9999
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0001
# Pattern: descending_triangle, Probability: 0.0004
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0010
# Pattern: double_top, Probability: 0.9985
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 0.0001
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0002
# Pattern: double_top, Probability: 0.9997
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0012
# Pattern: descending_triangle, Probability: 0.0023
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0045
# Pattern: double_top, Probability: 0.9920
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.0001
# Pattern: descending_triangle, Probability: 0.0002
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0007
# Pattern: double_top, Probability: 0.9990
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0344
# Pattern: descending_triangle, Probability: 0.0422
# Pattern: ascending_wedge, Probability: 0.0002
# Pattern: descending_wedge, Probability: 0.0583
# Pattern: double_top, Probability: 0.8649
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0057
# Pattern: descending_triangle, Probability: 0.0058
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0142
# Pattern: double_top, Probability: 0.9743
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.3651
# Pattern: descending_triangle, Probability: 0.4000
# Pattern: ascending_wedge, Probability: 0.0002
# Pattern: descending_wedge, Probability: 0.1281
# Pattern: double_top, Probability: 0.1066
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Pattern: ascending_triangle, Probability: 0.1753
# Pattern: descending_triangle, Probability: 0.2167
# Pattern: ascending_wedge, Probability: 0.0001
# Pattern: descending_wedge, Probability: 0.1836
# Pattern: double_top, Probability: 0.4244
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Pattern: ascending_triangle, Probability: 0.5775
# Pattern: descending_triangle, Probability: 0.4055
# Pattern: ascending_wedge, Probability: 0.0003
# Pattern: descending_wedge, Probability: 0.0115
# Pattern: double_top, Probability: 0.0052
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.8509
# Pattern: descending_triangle, Probability: 0.1436
# Pattern: ascending_wedge, Probability: 0.0013
# Pattern: descending_wedge, Probability: 0.0026
# Pattern: double_top, Probability: 0.0016
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.9196
# Pattern: descending_triangle, Probability: 0.0538
# Pattern: ascending_wedge, Probability: 0.0257
# Pattern: descending_wedge, Probability: 0.0008
# Pattern: double_top, Probability: 0.0001
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.6549
# Pattern: descending_triangle, Probability: 0.0043
# Pattern: ascending_wedge, Probability: 0.3404
# Pattern: descending_wedge, Probability: 0.0003
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.3340
# Pattern: descending_triangle, Probability: 0.6185
# Pattern: ascending_wedge, Probability: 0.0024
# Pattern: descending_wedge, Probability: 0.0446
# Pattern: double_top, Probability: 0.0004
# Pattern: double_bottom, Probability: 0.0001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.4591
# Pattern: descending_triangle, Probability: 0.4173
# Pattern: ascending_wedge, Probability: 0.0172
# Pattern: descending_wedge, Probability: 0.1046
# Pattern: double_top, Probability: 0.0016
# Pattern: double_bottom, Probability: 0.0002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Pattern: ascending_triangle, Probability: 0.0016
# Pattern: descending_triangle, Probability: 0.9935
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0048
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0202
# Pattern: descending_triangle, Probability: 0.9748
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0049
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0001
# Pattern: descending_triangle, Probability: 0.9998
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0028
# Pattern: descending_triangle, Probability: 0.9971
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0001
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 1.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0004
# Pattern: descending_triangle, Probability: 0.9996
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 1.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Pattern: ascending_triangle, Probability: 0.0001
# Pattern: descending_triangle, Probability: 0.9999
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 1.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0001
# Pattern: descending_triangle, Probability: 0.9999
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 1.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 1.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Pattern: ascending_triangle, Probability: 0.0000
# Pattern: descending_triangle, Probability: 1.0000
# Pattern: ascending_wedge, Probability: 0.0000
# Pattern: descending_wedge, Probability: 0.0000
# Pattern: double_top, Probability: 0.0000
# Pattern: double_bottom, Probability: 0.0000
